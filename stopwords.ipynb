# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
def remove_stop_words(string):
  stop_words = set(stopwords.words('english'))
  words=string.split()
  filtered_words=[word for word in words if word.lower() not in stop_words]
  new_string = ''.join(filtered_words)
  return new_string
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
input_string="this is an example sentence to remove stop words from"
result = remove_stop_words(input_string)
print("original string:", input_string)
print("modified string:", result)
from collections import Counter
def count_stop_words(text):
  """Counts the number of stop words in a given text."""
  stop_words = set(stopwords.words('english'))
  stop_word_counts = Counter(text.split())
  return stop_word_counts
text = "this is an example sentence to remove stop words from"
stop_word_counts = count_stop_words(text)
print(stop_word_counts)
# Out:
# original string: this is an example sentence to remove stop words from
# modified string: examplesentenceremovestopwords
# Counter({'this': 1, 'is': 1, 'an': 1, 'example': 1, 'sentence': 1, 'to': 1, 'remove': 1, 'stop': 1, 'words': 1, 'from': 1})

# %%
import matplotlib.pyplot as plt
from collections import Counter
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')

def plot_stopword_bar_graph(text):
    # Tokenize the text and convert to lowercase
    words = nltk.word_tokenize(text.lower())

    # Get English stopwords
    stop_words = set(stopwords.words('english'))

    # Filter out stopwords
    filtered_words = [word for word in words if word in stop_words]

    # Count the frequency of each stop word
    word_freq = Counter(filtered_words)

    # Sort the dictionary by frequency
    sorted_word_freq = dict(sorted(word_freq.items(), key=lambda item: item[1], reverse=True))

    # Plot the bar graph
    plt.figure(figsize=(10, 6))
    plt.bar(sorted_word_freq.keys(), sorted_word_freq.values(), color='skyblue')
    plt.xlabel('Stop Words')
    plt.ylabel('Frequency')
    plt.title('Frequency of Stop Words')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Example usage
text = "This is a sample text with some common English stopwords like is, a, the, and so on."
plot_stopword_bar_graph(text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
import matplotlib.pyplot as plt
stop_words = ["a", "an", "and", "are", "as", "at", "be", "but", "by", "for", "if", "in", "into", "is", "it", "no", "not", "of", "on", "or", "such", "that", "the", "their", "then", "there", "these", "they", "this", "to", "was", "will", "with"]
plt.bar(stop_words, len(stop_words))
plt.xlabel("Letter")
plt.ylabel("Count")
plt.title("Bar Graph of Letters in Stop Words")
plt.xticks(stop_words, rotation=90)
plt.show()
